# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 3s 53us/sample - loss: 1.4442 - accuracy: 0.6511 - val_loss: 0.7429 - val_accuracy: 0.8382
# Epoch 2/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.5888 - accuracy: 0.8551 - val_loss: 0.4465 - val_accuracy: 0.8827
# Epoch 3/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.4305 - accuracy: 0.8836 - val_loss: 0.3692 - val_accuracy: 0.8948
# Epoch 4/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.3727 - accuracy: 0.8953 - val_loss: 0.3315 - val_accuracy: 0.9038
# Epoch 5/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.3398 - accuracy: 0.9032 - val_loss: 0.3075 - val_accuracy: 0.9104
# Epoch 6/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.3167 - accuracy: 0.9096 - val_loss: 0.2898 - val_accuracy: 0.9169
# Epoch 7/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.2988 - accuracy: 0.9139 - val_loss: 0.2773 - val_accuracy: 0.9195
# Epoch 8/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.2836 - accuracy: 0.9186 - val_loss: 0.2636 - val_accuracy: 0.9222
# Epoch 9/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2706 - accuracy: 0.9227 - val_loss: 0.2526 - val_accuracy: 0.9272
# Epoch 10/50
# 48000/48000 [==============================] - 2s 41us/sample - loss: 0.2595 - accuracy: 0.9257 - val_loss: 0.2426 - val_accuracy: 0.9306
# Epoch 11/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.2491 - accuracy: 0.9285 - val_loss: 0.2342 - val_accuracy: 0.9326
# Epoch 12/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.2397 - accuracy: 0.9318 - val_loss: 0.2270 - val_accuracy: 0.9349
# Epoch 13/50
# 48000/48000 [==============================] - 3s 52us/sample - loss: 0.2311 - accuracy: 0.9340 - val_loss: 0.2200 - val_accuracy: 0.9375
# Epoch 14/50
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.2234 - accuracy: 0.9358 - val_loss: 0.2132 - val_accuracy: 0.9387
# Epoch 15/50
# 48000/48000 [==============================] - 2s 42us/sample - loss: 0.2159 - accuracy: 0.9378 - val_loss: 0.2075 - val_accuracy: 0.9400
# Epoch 16/50
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.2092 - accuracy: 0.9398 - val_loss: 0.2022 - val_accuracy: 0.9422
# Epoch 17/50
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.2025 - accuracy: 0.9420 - val_loss: 0.1963 - val_accuracy: 0.9433
# Epoch 18/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1967 - accuracy: 0.9432 - val_loss: 0.1918 - val_accuracy: 0.9447
# Epoch 19/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1907 - accuracy: 0.9450 - val_loss: 0.1888 - val_accuracy: 0.9464
# Epoch 20/50
# 48000/48000 [==============================] - 2s 41us/sample - loss: 0.1858 - accuracy: 0.9467 - val_loss: 0.1823 - val_accuracy: 0.9488
# Epoch 21/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1806 - accuracy: 0.9485 - val_loss: 0.1787 - val_accuracy: 0.9493
# Epoch 22/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1757 - accuracy: 0.9504 - val_loss: 0.1745 - val_accuracy: 0.9505
# Epoch 23/50
# 48000/48000 [==============================] - 3s 53us/sample - loss: 0.1709 - accuracy: 0.9514 - val_loss: 0.1716 - val_accuracy: 0.9503
# Epoch 24/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1669 - accuracy: 0.9525 - val_loss: 0.1670 - val_accuracy: 0.9521
# Epoch 25/50
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.1629 - accuracy: 0.9534 - val_loss: 0.1643 - val_accuracy: 0.9532
# Epoch 26/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1588 - accuracy: 0.9546 - val_loss: 0.1618 - val_accuracy: 0.9539
# Epoch 27/50
# 48000/48000 [==============================] - 2s 42us/sample - loss: 0.1550 - accuracy: 0.9560 - val_loss: 0.1593 - val_accuracy: 0.9544
# Epoch 28/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1513 - accuracy: 0.9567 - val_loss: 0.1561 - val_accuracy: 0.9555
# Epoch 29/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1479 - accuracy: 0.9579 - val_loss: 0.1538 - val_accuracy: 0.9554
# Epoch 30/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1445 - accuracy: 0.9586 - val_loss: 0.1510 - val_accuracy: 0.9566
# Epoch 31/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1414 - accuracy: 0.9595 - val_loss: 0.1491 - val_accuracy: 0.9578
# Epoch 32/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1384 - accuracy: 0.9605 - val_loss: 0.1466 - val_accuracy: 0.9582
# Epoch 33/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1354 - accuracy: 0.9615 - val_loss: 0.1446 - val_accuracy: 0.9589
# Epoch 34/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1327 - accuracy: 0.9623 - val_loss: 0.1421 - val_accuracy: 0.9590
# Epoch 35/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1298 - accuracy: 0.9636 - val_loss: 0.1401 - val_accuracy: 0.9600
# Epoch 36/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1274 - accuracy: 0.9641 - val_loss: 0.1386 - val_accuracy: 0.9606
# Epoch 37/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1247 - accuracy: 0.9646 - val_loss: 0.1372 - val_accuracy: 0.9603
# Epoch 38/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.1222 - accuracy: 0.9657 - val_loss: 0.1353 - val_accuracy: 0.9603
# Epoch 39/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1198 - accuracy: 0.9662 - val_loss: 0.1336 - val_accuracy: 0.9604
# Epoch 40/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1177 - accuracy: 0.9671 - val_loss: 0.1313 - val_accuracy: 0.9627
# Epoch 41/50
# 48000/48000 [==============================] - 2s 42us/sample - loss: 0.1153 - accuracy: 0.9676 - val_loss: 0.1300 - val_accuracy: 0.9622
# Epoch 42/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1131 - accuracy: 0.9684 - val_loss: 0.1293 - val_accuracy: 0.9627
# Epoch 43/50
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.1111 - accuracy: 0.9690 - val_loss: 0.1272 - val_accuracy: 0.9638
# Epoch 44/50
# 48000/48000 [==============================] - 2s 42us/sample - loss: 0.1091 - accuracy: 0.9695 - val_loss: 0.1259 - val_accuracy: 0.9638
# Epoch 45/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.1070 - accuracy: 0.9699 - val_loss: 0.1257 - val_accuracy: 0.9638
# Epoch 46/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.1053 - accuracy: 0.9706 - val_loss: 0.1231 - val_accuracy: 0.9649
# Epoch 47/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.1034 - accuracy: 0.9713 - val_loss: 0.1228 - val_accuracy: 0.9652
# Epoch 48/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.1016 - accuracy: 0.9717 - val_loss: 0.1206 - val_accuracy: 0.9657
# Epoch 49/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0996 - accuracy: 0.9721 - val_loss: 0.1209 - val_accuracy: 0.9655
# Epoch 50/50
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.0981 - accuracy: 0.9732 - val_loss: 0.1190 - val_accuracy: 0.9656
# 10000/10000 [==============================] - 1s 76us/sample - loss: 0.1174 - accuracy: 0.9650
#
# Test accuracy: 0.965
