# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

VALIDATION_SPLIT = 0.2

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255
X_test /= 255

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(NB_CLASSES, input_shape=(RESHAPED,), name='dense_layer',activation='softmax'))

model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 33us/sample - loss: 1.4268 - accuracy: 0.6405 - val_loss: 0.9061 - val_accuracy: 0.8242
# Epoch 2/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.8005 - accuracy: 0.8239 - val_loss: 0.6596 - val_accuracy: 0.8574
# Epoch 3/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.6463 - accuracy: 0.8494 - val_loss: 0.5622 - val_accuracy: 0.8723
# Epoch 4/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.5726 - accuracy: 0.8615 - val_loss: 0.5089 - val_accuracy: 0.8786
# Epoch 5/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.5282 - accuracy: 0.8687 - val_loss: 0.4744 - val_accuracy: 0.8840
# Epoch 6/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.4977 - accuracy: 0.8743 - val_loss: 0.4505 - val_accuracy: 0.8880
# Epoch 7/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.4752 - accuracy: 0.8781 - val_loss: 0.4323 - val_accuracy: 0.8911
# Epoch 8/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.4578 - accuracy: 0.8811 - val_loss: 0.4180 - val_accuracy: 0.8946
# Epoch 9/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.4437 - accuracy: 0.8836 - val_loss: 0.4064 - val_accuracy: 0.8962
# Epoch 10/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.4321 - accuracy: 0.8853 - val_loss: 0.3973 - val_accuracy: 0.8983
# Epoch 11/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.4223 - accuracy: 0.8875 - val_loss: 0.3887 - val_accuracy: 0.8994
# Epoch 12/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.4139 - accuracy: 0.8890 - val_loss: 0.3820 - val_accuracy: 0.9007
# Epoch 13/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.4065 - accuracy: 0.8904 - val_loss: 0.3758 - val_accuracy: 0.9019
# Epoch 14/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.4000 - accuracy: 0.8917 - val_loss: 0.3705 - val_accuracy: 0.9026
# Epoch 15/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.3942 - accuracy: 0.8928 - val_loss: 0.3657 - val_accuracy: 0.9032
# Epoch 16/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.3890 - accuracy: 0.8939 - val_loss: 0.3614 - val_accuracy: 0.9039
# Epoch 17/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.3843 - accuracy: 0.8947 - val_loss: 0.3576 - val_accuracy: 0.9036
# Epoch 18/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.3800 - accuracy: 0.8960 - val_loss: 0.3540 - val_accuracy: 0.9056
# Epoch 19/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.3760 - accuracy: 0.8966 - val_loss: 0.3508 - val_accuracy: 0.9064
# Epoch 20/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.3724 - accuracy: 0.8973 - val_loss: 0.3478 - val_accuracy: 0.9072
# 10000/10000 [==============================] - 1s 53us/sample - loss: 0.3484 - accuracy: 0.9064
#
# Test accuracy: 0.9064
