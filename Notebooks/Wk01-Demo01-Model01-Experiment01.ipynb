# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255
X_test /= 255

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(NB_CLASSES, input_shape=(RESHAPED,), name='dense_layer',activation='softmax'))

model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 1.3976 - accuracy: 0.6546 - val_loss: 0.9002 - val_accuracy: 0.8220
# Epoch 2/20
# 48000/48000 [==============================] - 1s 22us/sample - loss: 0.7956 - accuracy: 0.8261 - val_loss: 0.6584 - val_accuracy: 0.8579
# Epoch 3/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.6440 - accuracy: 0.8492 - val_loss: 0.5617 - val_accuracy: 0.8700
# Epoch 4/20
# 48000/48000 [==============================] - 1s 22us/sample - loss: 0.5708 - accuracy: 0.8606 - val_loss: 0.5085 - val_accuracy: 0.8791
# Epoch 5/20
# 48000/48000 [==============================] - 1s 23us/sample - loss: 0.5264 - accuracy: 0.8684 - val_loss: 0.4741 - val_accuracy: 0.8854
# Epoch 6/20
# 48000/48000 [==============================] - 1s 24us/sample - loss: 0.4959 - accuracy: 0.8734 - val_loss: 0.4496 - val_accuracy: 0.8885
# Epoch 7/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.4733 - accuracy: 0.8777 - val_loss: 0.4316 - val_accuracy: 0.8915
# Epoch 8/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.4559 - accuracy: 0.8808 - val_loss: 0.4173 - val_accuracy: 0.8930
# Epoch 9/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.4418 - accuracy: 0.8832 - val_loss: 0.4057 - val_accuracy: 0.8952
# Epoch 10/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.4302 - accuracy: 0.8856 - val_loss: 0.3959 - val_accuracy: 0.8960
# Epoch 11/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.4203 - accuracy: 0.8868 - val_loss: 0.3880 - val_accuracy: 0.8980
# Epoch 12/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.4119 - accuracy: 0.8884 - val_loss: 0.3809 - val_accuracy: 0.8992
# Epoch 13/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.4045 - accuracy: 0.8904 - val_loss: 0.3748 - val_accuracy: 0.9005
# Epoch 14/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.3981 - accuracy: 0.8917 - val_loss: 0.3694 - val_accuracy: 0.9014
# Epoch 15/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.3923 - accuracy: 0.8935 - val_loss: 0.3646 - val_accuracy: 0.9026
# Epoch 16/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.3872 - accuracy: 0.8944 - val_loss: 0.3602 - val_accuracy: 0.9031
# Epoch 17/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.3825 - accuracy: 0.8950 - val_loss: 0.3565 - val_accuracy: 0.9035
# Epoch 18/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.3782 - accuracy: 0.8961 - val_loss: 0.3530 - val_accuracy: 0.9043
# Epoch 19/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.3743 - accuracy: 0.8966 - val_loss: 0.3498 - val_accuracy: 0.9048
# Epoch 20/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.3707 - accuracy: 0.8975 - val_loss: 0.3468 - val_accuracy: 0.9058
# 10000/10000 [==============================] - 1s 60us/sample - loss: 0.3477 - accuracy: 0.9067
#
# Test accuracy: 0.9067
