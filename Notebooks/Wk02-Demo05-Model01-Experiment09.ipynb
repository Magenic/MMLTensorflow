# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 43us/sample - loss: 0.4083 - accuracy: 0.8777 - val_loss: 0.1768 - val_accuracy: 0.9499
# Epoch 2/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.2695 - accuracy: 0.9222 - val_loss: 0.1611 - val_accuracy: 0.9556
# Epoch 3/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.2461 - accuracy: 0.9299 - val_loss: 0.1531 - val_accuracy: 0.9554
# Epoch 4/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.2409 - accuracy: 0.9336 - val_loss: 0.1444 - val_accuracy: 0.9588
# Epoch 5/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.2326 - accuracy: 0.9364 - val_loss: 0.1436 - val_accuracy: 0.9617
# Epoch 6/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.2281 - accuracy: 0.9366 - val_loss: 0.1466 - val_accuracy: 0.9615
# Epoch 7/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.2244 - accuracy: 0.9395 - val_loss: 0.1426 - val_accuracy: 0.9619
# Epoch 8/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.2157 - accuracy: 0.9419 - val_loss: 0.1406 - val_accuracy: 0.9625
# Epoch 9/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.2111 - accuracy: 0.9439 - val_loss: 0.1336 - val_accuracy: 0.9650
# Epoch 10/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.2129 - accuracy: 0.9440 - val_loss: 0.1443 - val_accuracy: 0.9626
# Epoch 11/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.2046 - accuracy: 0.9462 - val_loss: 0.1458 - val_accuracy: 0.9623
# Epoch 12/20
# 48000/48000 [==============================] - 2s 37us/sample - loss: 0.1999 - accuracy: 0.9477 - val_loss: 0.1634 - val_accuracy: 0.9603
# Epoch 13/20
# 48000/48000 [==============================] - 2s 37us/sample - loss: 0.1953 - accuracy: 0.9486 - val_loss: 0.1431 - val_accuracy: 0.9646
# Epoch 14/20
# 48000/48000 [==============================] - 2s 37us/sample - loss: 0.1991 - accuracy: 0.9479 - val_loss: 0.1480 - val_accuracy: 0.9644
# Epoch 15/20
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.1959 - accuracy: 0.9485 - val_loss: 0.1435 - val_accuracy: 0.9629
# Epoch 16/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.1959 - accuracy: 0.9505 - val_loss: 0.1522 - val_accuracy: 0.9628
# Epoch 17/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.1909 - accuracy: 0.9502 - val_loss: 0.1485 - val_accuracy: 0.9664
# Epoch 18/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.1838 - accuracy: 0.9504 - val_loss: 0.1427 - val_accuracy: 0.9654
# Epoch 19/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.1868 - accuracy: 0.9514 - val_loss: 0.1488 - val_accuracy: 0.9668
# Epoch 20/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.1816 - accuracy: 0.9530 - val_loss: 0.1428 - val_accuracy: 0.9664
# 10000/10000 [==============================] - 1s 50us/sample - loss: 0.1397 - accuracy: 0.9681
#
# Test accuracy: 0.9681
