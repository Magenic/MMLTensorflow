# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 12s 242us/sample - loss: 1.6983 - accuracy: 0.4756 - val_loss: 0.8810 - val_accuracy: 0.8134
# Epoch 2/50
# 48000/48000 [==============================] - 6s 130us/sample - loss: 0.9133 - accuracy: 0.7243 - val_loss: 0.5241 - val_accuracy: 0.8708
# Epoch 3/50
# 48000/48000 [==============================] - 6s 130us/sample - loss: 0.6852 - accuracy: 0.7907 - val_loss: 0.4157 - val_accuracy: 0.8897
# Epoch 4/50
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.5894 - accuracy: 0.8214 - val_loss: 0.3633 - val_accuracy: 0.8992
# Epoch 5/50
# 48000/48000 [==============================] - 8s 165us/sample - loss: 0.5265 - accuracy: 0.8429 - val_loss: 0.3296 - val_accuracy: 0.9072
# Epoch 6/50
# 48000/48000 [==============================] - 12s 243us/sample - loss: 0.4838 - accuracy: 0.8556 - val_loss: 0.3074 - val_accuracy: 0.9128
# Epoch 7/50
# 48000/48000 [==============================] - 14s 290us/sample - loss: 0.4510 - accuracy: 0.8671 - val_loss: 0.2895 - val_accuracy: 0.9165
# Epoch 8/50
# 48000/48000 [==============================] - 41s 848us/sample - loss: 0.4241 - accuracy: 0.8755 - val_loss: 0.2747 - val_accuracy: 0.9201acy: 0.87
# Epoch 9/50
# 48000/48000 [==============================] - 24s 490us/sample - loss: 0.4013 - accuracy: 0.8820 - val_loss: 0.2622 - val_accuracy: 0.9242
# Epoch 10/50
# 48000/48000 [==============================] - 11s 221us/sample - loss: 0.3847 - accuracy: 0.8870 - val_loss: 0.2516 - val_accuracy: 0.9267
# Epoch 11/50
# 48000/48000 [==============================] - 8s 162us/sample - loss: 0.3655 - accuracy: 0.8925 - val_loss: 0.2429 - val_accuracy: 0.9293
# Epoch 12/50
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.3544 - accuracy: 0.8957 - val_loss: 0.2346 - val_accuracy: 0.9313
# Epoch 13/50
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.3396 - accuracy: 0.9009 - val_loss: 0.2278 - val_accuracy: 0.9338
# Epoch 14/50
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.3346 - accuracy: 0.9022 - val_loss: 0.2202 - val_accuracy: 0.9361
# Epoch 15/50
# 48000/48000 [==============================] - 8s 172us/sample - loss: 0.3223 - accuracy: 0.9055 - val_loss: 0.2142 - val_accuracy: 0.9377
# Epoch 16/50
# 48000/48000 [==============================] - 25s 511us/sample - loss: 0.3152 - accuracy: 0.9073 - val_loss: 0.2086 - val_accuracy: 0.9391
# Epoch 17/50
# 48000/48000 [==============================] - 42s 877us/sample - loss: 0.3028 - accuracy: 0.9119 - val_loss: 0.2036 - val_accuracy: 0.9410
# Epoch 18/50
# 48000/48000 [==============================] - 11s 237us/sample - loss: 0.2974 - accuracy: 0.9120 - val_loss: 0.1990 - val_accuracy: 0.9423
# Epoch 19/50
# 48000/48000 [==============================] - 7s 156us/sample - loss: 0.2893 - accuracy: 0.9152 - val_loss: 0.1944 - val_accuracy: 0.9442
# Epoch 20/50
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2879 - accuracy: 0.9161 - val_loss: 0.1903 - val_accuracy: 0.9445
# Epoch 21/50
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.2769 - accuracy: 0.9184 - val_loss: 0.1866 - val_accuracy: 0.9456
# Epoch 22/50
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2713 - accuracy: 0.9212 - val_loss: 0.1831 - val_accuracy: 0.9464
# Epoch 23/50
# 48000/48000 [==============================] - 7s 150us/sample - loss: 0.2679 - accuracy: 0.9210 - val_loss: 0.1795 - val_accuracy: 0.9472
# Epoch 24/50
# 48000/48000 [==============================] - 16s 340us/sample - loss: 0.2624 - accuracy: 0.9229 - val_loss: 0.1769 - val_accuracy: 0.9474
# Epoch 25/50
#  5632/48000 [==>...........................] - ETA: 1:01 - loss: 0.2567 - accuracy: 0.9279
