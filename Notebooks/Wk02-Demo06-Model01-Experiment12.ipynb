# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 100
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 100)               78500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 100)               10100
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1010
# =================================================================
# Total params: 89,610
# Trainable params: 89,610
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 42us/sample - loss: 1.5148 - accuracy: 0.5260 - val_loss: 0.6280 - val_accuracy: 0.8583
# Epoch 2/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.7044 - accuracy: 0.7888 - val_loss: 0.3781 - val_accuracy: 0.8987
# Epoch 3/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.5197 - accuracy: 0.8461 - val_loss: 0.3064 - val_accuracy: 0.9141
# Epoch 4/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.4409 - accuracy: 0.8685 - val_loss: 0.2694 - val_accuracy: 0.9226
# Epoch 5/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.3897 - accuracy: 0.8849 - val_loss: 0.2428 - val_accuracy: 0.9289
# Epoch 6/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.3587 - accuracy: 0.8949 - val_loss: 0.2246 - val_accuracy: 0.9351
# Epoch 7/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.3288 - accuracy: 0.9037 - val_loss: 0.2060 - val_accuracy: 0.9398
# Epoch 8/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.3079 - accuracy: 0.9107 - val_loss: 0.1958 - val_accuracy: 0.9430
# Epoch 9/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.2878 - accuracy: 0.9167 - val_loss: 0.1824 - val_accuracy: 0.9484
# Epoch 10/20
# 48000/48000 [==============================] - 2s 33us/sample - loss: 0.2725 - accuracy: 0.9200 - val_loss: 0.1746 - val_accuracy: 0.9492
# Epoch 11/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.2567 - accuracy: 0.9251 - val_loss: 0.1667 - val_accuracy: 0.9513
# Epoch 12/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.2463 - accuracy: 0.9290 - val_loss: 0.1604 - val_accuracy: 0.9532
# Epoch 13/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.2322 - accuracy: 0.9320 - val_loss: 0.1518 - val_accuracy: 0.9553
# Epoch 14/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.2264 - accuracy: 0.9331 - val_loss: 0.1469 - val_accuracy: 0.9575
# Epoch 15/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.2164 - accuracy: 0.9373 - val_loss: 0.1416 - val_accuracy: 0.9581
# Epoch 16/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.2084 - accuracy: 0.9388 - val_loss: 0.1375 - val_accuracy: 0.9592
# Epoch 17/20
# 48000/48000 [==============================] - 2s 33us/sample - loss: 0.1974 - accuracy: 0.9423 - val_loss: 0.1340 - val_accuracy: 0.9607
# Epoch 18/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.1956 - accuracy: 0.9428 - val_loss: 0.1306 - val_accuracy: 0.9617
# Epoch 19/20
# 48000/48000 [==============================] - 2s 31us/sample - loss: 0.1891 - accuracy: 0.9441 - val_loss: 0.1273 - val_accuracy: 0.9620
# Epoch 20/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.1840 - accuracy: 0.9466 - val_loss: 0.1232 - val_accuracy: 0.9634
# 10000/10000 [==============================] - 1s 58us/sample - loss: 0.1220 - accuracy: 0.9637
#
# Test accuracy: 0.9637
