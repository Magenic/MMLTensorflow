# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.1)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 44us/sample - loss: 2.3390 - accuracy: 0.2446 - val_loss: 1.7023 - val_accuracy: 0.3613
# Epoch 2/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 1.9306 - accuracy: 0.2637 - val_loss: 1.6154 - val_accuracy: 0.3823
# Epoch 3/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 1.9354 - accuracy: 0.2572 - val_loss: 1.6656 - val_accuracy: 0.3658
# Epoch 4/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 1.9504 - accuracy: 0.2534 - val_loss: 1.6468 - val_accuracy: 0.3825
# Epoch 5/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 1.9746 - accuracy: 0.2458 - val_loss: 1.6138 - val_accuracy: 0.3783
# Epoch 6/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 2.1545 - accuracy: 0.1665 - val_loss: 2.0537 - val_accuracy: 0.2017
# Epoch 7/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 2.1830 - accuracy: 0.1533 - val_loss: 2.1060 - val_accuracy: 0.1954
# Epoch 8/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 2.2853 - accuracy: 0.1160 - val_loss: 2.3066 - val_accuracy: 0.1060
# Epoch 9/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 2.3068 - accuracy: 0.1061 - val_loss: 2.3086 - val_accuracy: 0.1060
# Epoch 10/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 2.3073 - accuracy: 0.1058 - val_loss: 2.3077 - val_accuracy: 0.1060
# Epoch 11/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 2.3081 - accuracy: 0.1061 - val_loss: 2.3080 - val_accuracy: 0.1035
# Epoch 12/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 2.3068 - accuracy: 0.1076 - val_loss: 2.3073 - val_accuracy: 0.0988
# Epoch 13/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 2.3071 - accuracy: 0.1049 - val_loss: 2.3058 - val_accuracy: 0.1060
# Epoch 14/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 2.3078 - accuracy: 0.1038 - val_loss: 2.3058 - val_accuracy: 0.1081
# Epoch 15/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 2.3075 - accuracy: 0.1059 - val_loss: 2.3046 - val_accuracy: 0.0996
# Epoch 16/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 2.3068 - accuracy: 0.1061 - val_loss: 2.3070 - val_accuracy: 0.1081
# Epoch 17/20
# 48000/48000 [==============================] - 2s 37us/sample - loss: 2.3071 - accuracy: 0.1060 - val_loss: 2.3126 - val_accuracy: 0.0998
# Epoch 18/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 2.3076 - accuracy: 0.1056 - val_loss: 2.3107 - val_accuracy: 0.0998
# Epoch 19/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 2.3075 - accuracy: 0.1057 - val_loss: 2.3072 - val_accuracy: 0.0956
# Epoch 20/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 2.3069 - accuracy: 0.1048 - val_loss: 2.3088 - val_accuracy: 0.0996
# 10000/10000 [==============================] - 1s 51us/sample - loss: 2.3064 - accuracy: 0.1032
#
# Test accuracy: 0.1032
