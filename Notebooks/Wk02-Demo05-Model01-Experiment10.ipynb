# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 48us/sample - loss: 1.3862 - accuracy: 0.5676 - val_loss: 0.5280 - val_accuracy: 0.8766
# Epoch 2/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.6153 - accuracy: 0.8131 - val_loss: 0.3456 - val_accuracy: 0.9058
# Epoch 3/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.4689 - accuracy: 0.8621 - val_loss: 0.2852 - val_accuracy: 0.9201
# Epoch 4/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 0.3985 - accuracy: 0.8809 - val_loss: 0.2542 - val_accuracy: 0.9286
# Epoch 5/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.3551 - accuracy: 0.8964 - val_loss: 0.2295 - val_accuracy: 0.9341
# Epoch 6/20
# 48000/48000 [==============================] - 2s 37us/sample - loss: 0.3231 - accuracy: 0.9055 - val_loss: 0.2129 - val_accuracy: 0.9376
# Epoch 7/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.2969 - accuracy: 0.9135 - val_loss: 0.2003 - val_accuracy: 0.9417
# Epoch 8/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.2763 - accuracy: 0.9199 - val_loss: 0.1871 - val_accuracy: 0.9455
# Epoch 9/20
# 48000/48000 [==============================] - 2s 37us/sample - loss: 0.2579 - accuracy: 0.9246 - val_loss: 0.1760 - val_accuracy: 0.9484
# Epoch 10/20
# 48000/48000 [==============================] - 2s 38us/sample - loss: 0.2433 - accuracy: 0.9286 - val_loss: 0.1662 - val_accuracy: 0.9525
# Epoch 11/20
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.2318 - accuracy: 0.9331 - val_loss: 0.1594 - val_accuracy: 0.9535
# Epoch 12/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.2200 - accuracy: 0.9356 - val_loss: 0.1514 - val_accuracy: 0.9552
# Epoch 13/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.2091 - accuracy: 0.9397 - val_loss: 0.1450 - val_accuracy: 0.9563
# Epoch 14/20
# 48000/48000 [==============================] - 2s 37us/sample - loss: 0.1981 - accuracy: 0.9419 - val_loss: 0.1402 - val_accuracy: 0.9583
# Epoch 15/20
# 48000/48000 [==============================] - 2s 38us/sample - loss: 0.1918 - accuracy: 0.9429 - val_loss: 0.1360 - val_accuracy: 0.9588
# Epoch 16/20
# 48000/48000 [==============================] - 2s 38us/sample - loss: 0.1801 - accuracy: 0.9467 - val_loss: 0.1304 - val_accuracy: 0.9618
# Epoch 17/20
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.1730 - accuracy: 0.9486 - val_loss: 0.1271 - val_accuracy: 0.9613
# Epoch 18/20
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.1688 - accuracy: 0.9496 - val_loss: 0.1233 - val_accuracy: 0.9628
# Epoch 19/20
# 48000/48000 [==============================] - 2s 39us/sample - loss: 0.1616 - accuracy: 0.9510 - val_loss: 0.1195 - val_accuracy: 0.9642
# Epoch 20/20
# 48000/48000 [==============================] - 2s 38us/sample - loss: 0.1550 - accuracy: 0.9541 - val_loss: 0.1169 - val_accuracy: 0.9659
# 10000/10000 [==============================] - 1s 57us/sample - loss: 0.1123 - accuracy: 0.9662
#
# Test accuracy: 0.9662
