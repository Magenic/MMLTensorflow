# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 64
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 3s 58us/sample - loss: 1.0762 - accuracy: 0.6723 - val_loss: 0.3963 - val_accuracy: 0.8928
# Epoch 2/20
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.4899 - accuracy: 0.8541 - val_loss: 0.2847 - val_accuracy: 0.9178
# Epoch 3/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.3841 - accuracy: 0.8880 - val_loss: 0.2393 - val_accuracy: 0.9295
# Epoch 4/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.3241 - accuracy: 0.9056 - val_loss: 0.2103 - val_accuracy: 0.9385
# Epoch 5/20
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.2863 - accuracy: 0.9164 - val_loss: 0.1880 - val_accuracy: 0.9450
# Epoch 6/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.2606 - accuracy: 0.9241 - val_loss: 0.1742 - val_accuracy: 0.9512
# Epoch 7/20
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.2369 - accuracy: 0.9311 - val_loss: 0.1602 - val_accuracy: 0.9532
# Epoch 8/20
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.2179 - accuracy: 0.9358 - val_loss: 0.1507 - val_accuracy: 0.9566
# Epoch 9/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.2056 - accuracy: 0.9397 - val_loss: 0.1425 - val_accuracy: 0.9579
# Epoch 10/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.1915 - accuracy: 0.9426 - val_loss: 0.1346 - val_accuracy: 0.9617
# Epoch 11/20
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.1823 - accuracy: 0.9470 - val_loss: 0.1303 - val_accuracy: 0.9628
# Epoch 12/20
# 48000/48000 [==============================] - 3s 52us/sample - loss: 0.1729 - accuracy: 0.9488 - val_loss: 0.1238 - val_accuracy: 0.9642
# Epoch 13/20
# 48000/48000 [==============================] - 2s 47us/sample - loss: 0.1634 - accuracy: 0.9517 - val_loss: 0.1191 - val_accuracy: 0.9653
# Epoch 14/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.1523 - accuracy: 0.9547 - val_loss: 0.1169 - val_accuracy: 0.9653
# Epoch 15/20
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.1472 - accuracy: 0.9565 - val_loss: 0.1121 - val_accuracy: 0.9665
# Epoch 16/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.1421 - accuracy: 0.9580 - val_loss: 0.1105 - val_accuracy: 0.9672
# Epoch 17/20
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.1350 - accuracy: 0.9600 - val_loss: 0.1063 - val_accuracy: 0.9686
# Epoch 18/20
# 48000/48000 [==============================] - 3s 53us/sample - loss: 0.1315 - accuracy: 0.9610 - val_loss: 0.1053 - val_accuracy: 0.9697
# Epoch 19/20
# 48000/48000 [==============================] - 2s 50us/sample - loss: 0.1255 - accuracy: 0.9614 - val_loss: 0.1025 - val_accuracy: 0.9702
# Epoch 20/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.1218 - accuracy: 0.9646 - val_loss: 0.1022 - val_accuracy: 0.9706
# 10000/10000 [==============================] - 0s 40us/sample - loss: 0.0939 - accuracy: 0.9704
#
# Test accuracy: 0.9704
