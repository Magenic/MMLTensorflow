# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 37us/sample - loss: 1.3929 - accuracy: 0.5622 - val_loss: 0.5430 - val_accuracy: 0.8702
# Epoch 2/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.6265 - accuracy: 0.8128 - val_loss: 0.3491 - val_accuracy: 0.9060
# Epoch 3/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.4679 - accuracy: 0.8617 - val_loss: 0.2834 - val_accuracy: 0.9204
# Epoch 4/20
# 48000/48000 [==============================] - 1s 31us/sample - loss: 0.3908 - accuracy: 0.8856 - val_loss: 0.2478 - val_accuracy: 0.9283
# Epoch 5/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.3480 - accuracy: 0.8990 - val_loss: 0.2235 - val_accuracy: 0.9338
# Epoch 6/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.3147 - accuracy: 0.9086 - val_loss: 0.2048 - val_accuracy: 0.9401
# Epoch 7/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.2911 - accuracy: 0.9158 - val_loss: 0.1898 - val_accuracy: 0.9463
# Epoch 8/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.2702 - accuracy: 0.9216 - val_loss: 0.1790 - val_accuracy: 0.9491
# Epoch 9/20
# 48000/48000 [==============================] - 2s 33us/sample - loss: 0.2539 - accuracy: 0.9272 - val_loss: 0.1672 - val_accuracy: 0.9528
# Epoch 10/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.2378 - accuracy: 0.9304 - val_loss: 0.1581 - val_accuracy: 0.9543
# Epoch 11/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.2254 - accuracy: 0.9330 - val_loss: 0.1516 - val_accuracy: 0.9560
# Epoch 12/20
# 48000/48000 [==============================] - 2s 38us/sample - loss: 0.2132 - accuracy: 0.9376 - val_loss: 0.1465 - val_accuracy: 0.9574
# Epoch 13/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.2025 - accuracy: 0.9402 - val_loss: 0.1412 - val_accuracy: 0.9590
# Epoch 14/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.1962 - accuracy: 0.9420 - val_loss: 0.1351 - val_accuracy: 0.9613
# Epoch 15/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.1888 - accuracy: 0.9449 - val_loss: 0.1315 - val_accuracy: 0.9618
# Epoch 16/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.1818 - accuracy: 0.9467 - val_loss: 0.1283 - val_accuracy: 0.9631
# Epoch 17/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.1690 - accuracy: 0.9503 - val_loss: 0.1249 - val_accuracy: 0.9640
# Epoch 18/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.1662 - accuracy: 0.9513 - val_loss: 0.1202 - val_accuracy: 0.9653
# Epoch 19/20
# 48000/48000 [==============================] - 2s 33us/sample - loss: 0.1606 - accuracy: 0.9527 - val_loss: 0.1181 - val_accuracy: 0.9658
# Epoch 20/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 0.1557 - accuracy: 0.9544 - val_loss: 0.1143 - val_accuracy: 0.9666
# 10000/10000 [==============================] - 0s 41us/sample - loss: 0.1106 - accuracy: 0.9652
#
# Test accuracy: 0.9652
