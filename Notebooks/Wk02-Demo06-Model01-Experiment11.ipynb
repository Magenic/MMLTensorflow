# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 10
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 10)                7850
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 10)                110
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                110
# =================================================================
# Total params: 8,070
# Trainable params: 8,070
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 36us/sample - loss: 2.2346 - accuracy: 0.1667 - val_loss: 2.0221 - val_accuracy: 0.3769
# Epoch 2/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 2.0054 - accuracy: 0.2675 - val_loss: 1.7590 - val_accuracy: 0.5014
# Epoch 3/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.8552 - accuracy: 0.3554 - val_loss: 1.5648 - val_accuracy: 0.6387
# Epoch 4/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.7322 - accuracy: 0.4166 - val_loss: 1.4165 - val_accuracy: 0.7035
# Epoch 5/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.6472 - accuracy: 0.4480 - val_loss: 1.3077 - val_accuracy: 0.7326
# Epoch 6/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 1.5787 - accuracy: 0.4682 - val_loss: 1.2257 - val_accuracy: 0.7533
# Epoch 7/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 1.5276 - accuracy: 0.4875 - val_loss: 1.1540 - val_accuracy: 0.7658
# Epoch 8/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.4829 - accuracy: 0.5022 - val_loss: 1.1016 - val_accuracy: 0.7768
# Epoch 9/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.4400 - accuracy: 0.5160 - val_loss: 1.0471 - val_accuracy: 0.7864
# Epoch 10/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 1.4122 - accuracy: 0.5242 - val_loss: 1.0040 - val_accuracy: 0.7934
# Epoch 11/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.3744 - accuracy: 0.5312 - val_loss: 0.9670 - val_accuracy: 0.7973
# Epoch 12/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 1.3542 - accuracy: 0.5384 - val_loss: 0.9324 - val_accuracy: 0.8023
# Epoch 13/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.3199 - accuracy: 0.5465 - val_loss: 0.9035 - val_accuracy: 0.8091
# Epoch 14/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.2969 - accuracy: 0.5520 - val_loss: 0.8718 - val_accuracy: 0.8127
# Epoch 15/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.2830 - accuracy: 0.5586 - val_loss: 0.8476 - val_accuracy: 0.8213
# Epoch 16/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 1.2598 - accuracy: 0.5654 - val_loss: 0.8230 - val_accuracy: 0.8291
# Epoch 17/20
# 48000/48000 [==============================] - 2s 34us/sample - loss: 1.2450 - accuracy: 0.5689 - val_loss: 0.8019 - val_accuracy: 0.8330
# Epoch 18/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 1.2249 - accuracy: 0.5786 - val_loss: 0.7813 - val_accuracy: 0.8402
# Epoch 19/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 1.2130 - accuracy: 0.5829 - val_loss: 0.7572 - val_accuracy: 0.8503
# Epoch 20/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 1.1947 - accuracy: 0.5872 - val_loss: 0.7362 - val_accuracy: 0.8560
# 10000/10000 [==============================] - 0s 40us/sample - loss: 0.7344 - accuracy: 0.8506
#
# Test accuracy: 0.8506
