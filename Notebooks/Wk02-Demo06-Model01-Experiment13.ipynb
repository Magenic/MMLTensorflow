# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 1000
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 1000)              785000
# _________________________________________________________________
# dropout (Dropout)            (None, 1000)              0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 1000)              1001000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                10010
# =================================================================
# Total params: 1,796,010
# Trainable params: 1,796,010
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.5674 - accuracy: 0.8438 - val_loss: 0.2310 - val_accuracy: 0.9326
# Epoch 2/20
# 48000/48000 [==============================] - 5s 101us/sample - loss: 0.2380 - accuracy: 0.9302 - val_loss: 0.1670 - val_accuracy: 0.9534
# Epoch 3/20
# 48000/48000 [==============================] - 6s 115us/sample - loss: 0.1757 - accuracy: 0.9488 - val_loss: 0.1372 - val_accuracy: 0.9609
# Epoch 4/20
# 48000/48000 [==============================] - 5s 111us/sample - loss: 0.1420 - accuracy: 0.9581 - val_loss: 0.1165 - val_accuracy: 0.9655
# Epoch 5/20
# 48000/48000 [==============================] - 8s 176us/sample - loss: 0.1172 - accuracy: 0.9659 - val_loss: 0.1038 - val_accuracy: 0.9685
# Epoch 6/20
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.0991 - accuracy: 0.9702 - val_loss: 0.0959 - val_accuracy: 0.9716
# Epoch 7/20
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.0853 - accuracy: 0.9750 - val_loss: 0.0921 - val_accuracy: 0.9718
# Epoch 8/20
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.0743 - accuracy: 0.9777 - val_loss: 0.0837 - val_accuracy: 0.9737
# Epoch 9/20
# 48000/48000 [==============================] - 7s 156us/sample - loss: 0.0640 - accuracy: 0.9814 - val_loss: 0.0793 - val_accuracy: 0.9748
# Epoch 10/20
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.0567 - accuracy: 0.9832 - val_loss: 0.0734 - val_accuracy: 0.9774
# Epoch 11/20
# 48000/48000 [==============================] - 7s 155us/sample - loss: 0.0493 - accuracy: 0.9859 - val_loss: 0.0749 - val_accuracy: 0.9773
# Epoch 12/20
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.0432 - accuracy: 0.9871 - val_loss: 0.0737 - val_accuracy: 0.9771
# Epoch 13/20
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.0397 - accuracy: 0.9881 - val_loss: 0.0700 - val_accuracy: 0.9783
# Epoch 14/20
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.0335 - accuracy: 0.9904 - val_loss: 0.0692 - val_accuracy: 0.9790
# Epoch 15/20
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.0306 - accuracy: 0.9913 - val_loss: 0.0715 - val_accuracy: 0.9788
# Epoch 16/20
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.0288 - accuracy: 0.9912 - val_loss: 0.0691 - val_accuracy: 0.9801
# Epoch 17/20
# 48000/48000 [==============================] - 9s 181us/sample - loss: 0.0237 - accuracy: 0.9935 - val_loss: 0.0667 - val_accuracy: 0.9807
# Epoch 18/20
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0702 - val_accuracy: 0.9804
# Epoch 19/20
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.0198 - accuracy: 0.9945 - val_loss: 0.0679 - val_accuracy: 0.9812
# Epoch 20/20
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.0177 - accuracy: 0.9951 - val_loss: 0.0665 - val_accuracy: 0.9806
# 10000/10000 [==============================] - 26s 3ms/sample - loss: 0.0577 - accuracy: 0.9839
#
# Test accuracy: 0.9839
