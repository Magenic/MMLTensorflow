# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 256
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 2s 38us/sample - loss: 1.6740 - accuracy: 0.4676 - val_loss: 0.8122 - val_accuracy: 0.8431
# Epoch 2/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.8112 - accuracy: 0.7601 - val_loss: 0.4444 - val_accuracy: 0.8894
# Epoch 3/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.5816 - accuracy: 0.8275 - val_loss: 0.3481 - val_accuracy: 0.9053
# Epoch 4/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.4852 - accuracy: 0.8564 - val_loss: 0.3038 - val_accuracy: 0.9150
# Epoch 5/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.4294 - accuracy: 0.8735 - val_loss: 0.2763 - val_accuracy: 0.9218
# Epoch 6/20
# 48000/48000 [==============================] - 1s 24us/sample - loss: 0.3935 - accuracy: 0.8852 - val_loss: 0.2550 - val_accuracy: 0.9270
# Epoch 7/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.3616 - accuracy: 0.8949 - val_loss: 0.2405 - val_accuracy: 0.9314
# Epoch 8/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.3382 - accuracy: 0.9002 - val_loss: 0.2261 - val_accuracy: 0.9343
# Epoch 9/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.3187 - accuracy: 0.9057 - val_loss: 0.2159 - val_accuracy: 0.9371
# Epoch 10/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.3012 - accuracy: 0.9125 - val_loss: 0.2046 - val_accuracy: 0.9398
# Epoch 11/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.2883 - accuracy: 0.9149 - val_loss: 0.1959 - val_accuracy: 0.9435
# Epoch 12/20
# 48000/48000 [==============================] - 1s 28us/sample - loss: 0.2753 - accuracy: 0.9185 - val_loss: 0.1881 - val_accuracy: 0.9456
# Epoch 13/20
# 48000/48000 [==============================] - 1s 27us/sample - loss: 0.2626 - accuracy: 0.9235 - val_loss: 0.1809 - val_accuracy: 0.9473
# Epoch 14/20
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.2499 - accuracy: 0.9276 - val_loss: 0.1749 - val_accuracy: 0.9489
# Epoch 15/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.2429 - accuracy: 0.9284 - val_loss: 0.1678 - val_accuracy: 0.9503
# Epoch 16/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.2311 - accuracy: 0.9316 - val_loss: 0.1630 - val_accuracy: 0.9523
# Epoch 17/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.2243 - accuracy: 0.9348 - val_loss: 0.1567 - val_accuracy: 0.9547
# Epoch 18/20
# 48000/48000 [==============================] - 1s 30us/sample - loss: 0.2173 - accuracy: 0.9357 - val_loss: 0.1529 - val_accuracy: 0.9555
# Epoch 19/20
# 48000/48000 [==============================] - 1s 26us/sample - loss: 0.2095 - accuracy: 0.9385 - val_loss: 0.1488 - val_accuracy: 0.9569
# Epoch 20/20
# 48000/48000 [==============================] - 1s 25us/sample - loss: 0.2015 - accuracy: 0.9407 - val_loss: 0.1449 - val_accuracy: 0.9574
# 10000/10000 [==============================] - 1s 81us/sample - loss: 0.1431 - accuracy: 0.9573
#
# Test accuracy: 0.9573
