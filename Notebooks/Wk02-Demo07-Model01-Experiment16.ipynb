# %%
import tensorflow as tf
from tensorflow import keras

EPOCHS = 20
BATCH_SIZE = 256
VERBOSE = 1
NB_CLASSES = 10

N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

DROPOUT = 0.3

mnist = keras.datasets.mnist 
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255.0
X_test /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)


model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer',activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_dense_layer',activation='softmax'))

#0.001 is the default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(X_test, Y_test)
print()
print('Test accuracy:', test_acc)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_dense_layer (Dense)    (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# hidden_dense_layer (Dense)   (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_dense_layer (Dense)   (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 1s 29us/sample - loss: 1.7101 - accuracy: 0.4685 - val_loss: 0.8659 - val_accuracy: 0.8159
# Epoch 2/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.8294 - accuracy: 0.7534 - val_loss: 0.4524 - val_accuracy: 0.8857
# Epoch 3/20
# 48000/48000 [==============================] - 1s 20us/sample - loss: 0.5872 - accuracy: 0.8237 - val_loss: 0.3508 - val_accuracy: 0.9031
# Epoch 4/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.4852 - accuracy: 0.8568 - val_loss: 0.3010 - val_accuracy: 0.9154
# Epoch 5/20
# 48000/48000 [==============================] - 1s 22us/sample - loss: 0.4261 - accuracy: 0.8747 - val_loss: 0.2708 - val_accuracy: 0.9225
# Epoch 6/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.3875 - accuracy: 0.8864 - val_loss: 0.2494 - val_accuracy: 0.9282
# Epoch 7/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.3576 - accuracy: 0.8949 - val_loss: 0.2336 - val_accuracy: 0.9333
# Epoch 8/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.3292 - accuracy: 0.9045 - val_loss: 0.2182 - val_accuracy: 0.9369
# Epoch 9/20
# 48000/48000 [==============================] - 1s 20us/sample - loss: 0.3092 - accuracy: 0.9090 - val_loss: 0.2068 - val_accuracy: 0.9417
# Epoch 10/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.2912 - accuracy: 0.9151 - val_loss: 0.1969 - val_accuracy: 0.9428
# Epoch 11/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.2802 - accuracy: 0.9184 - val_loss: 0.1889 - val_accuracy: 0.9459
# Epoch 12/20
# 48000/48000 [==============================] - 1s 20us/sample - loss: 0.2662 - accuracy: 0.9238 - val_loss: 0.1809 - val_accuracy: 0.9480
# Epoch 13/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.2508 - accuracy: 0.9263 - val_loss: 0.1728 - val_accuracy: 0.9508
# Epoch 14/20
# 48000/48000 [==============================] - 1s 20us/sample - loss: 0.2444 - accuracy: 0.9283 - val_loss: 0.1683 - val_accuracy: 0.9512
# Epoch 15/20
# 48000/48000 [==============================] - 1s 19us/sample - loss: 0.2321 - accuracy: 0.9319 - val_loss: 0.1612 - val_accuracy: 0.9537
# Epoch 16/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.2230 - accuracy: 0.9347 - val_loss: 0.1570 - val_accuracy: 0.9542
# Epoch 17/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.2186 - accuracy: 0.9355 - val_loss: 0.1524 - val_accuracy: 0.9558
# Epoch 18/20
# 48000/48000 [==============================] - 1s 20us/sample - loss: 0.2097 - accuracy: 0.9384 - val_loss: 0.1475 - val_accuracy: 0.9563
# Epoch 19/20
# 48000/48000 [==============================] - 1s 20us/sample - loss: 0.2025 - accuracy: 0.9406 - val_loss: 0.1433 - val_accuracy: 0.9582
# Epoch 20/20
# 48000/48000 [==============================] - 1s 21us/sample - loss: 0.1974 - accuracy: 0.9415 - val_loss: 0.1405 - val_accuracy: 0.9588
# 10000/10000 [==============================] - 0s 44us/sample - loss: 0.1360 - accuracy: 0.9585
#
# Test accuracy: 0.9585
